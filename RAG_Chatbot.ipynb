# %%
# !pip install -U langchain-core langchain-community langchain-openai langchain_huggingface langchain faiss-cpu huggingface_hub

# %% [markdown]
# Environment Set-UP

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['HUGGINGFACEHUB_API_TOKEN']=os.getenv('Hf_Token')
# langsmith tracing
os.environ['LANGCHAIN_TRACING_V2']='true'
os.environ['LANGCHAIN_PROJECT']=os.getenv('LANGCHAIN_PROJECT')
os.environ['LANGCHAIN_API_KEY']=os.getenv('LANGCHAIN_API_KEY')
os.environ['OPENAI_API_KEY']=os.getenv('OPENAI_API_KEY')

# %%
# using OpenAI
# from langchain_openai import ChatOpenAI
# llm=ChatOpenAI(model='gpt-4o')
# print(llm)

# using HUggingFace HUb
from langchain_huggingface import HuggingFaceEndpoint

llm=HuggingFaceEndpoint(
    mode='microsoft/Phi-3-mini-4k-instruct',
    task='text_generation'
)
# Out:
# profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x7bdcf6c9f950> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7bdcf6dad9a0> root_client=<openai.OpenAI object at 0x7bdcf6cff950> root_async_client=<openai.AsyncOpenAI object at 0x7bdcf6c9f980> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
#input and get response
print(llm.invoke('can you provide me some free api keys'))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_4106/4245342252.py in <cell line: 0>()
#       1 #input and get response
# ----> 2 print(llm.invoke('can you provide me some free api keys'))
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     452             cast(
#     453                 "ChatGeneration",
# --> 454                 self.generate_prompt(
#     455                     [self._convert_input(input)],
#     456                     stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1183     ) -> LLMResult:
#    1184         prompt_messages = [p.to_messages() for p in prompts]
# ...
